# %%
from ultralytics import YOLO
import torch

model = YOLO('yolov8n-cls.pt').load("YoloV8n.pt")
# Out:
# Transferred 150/158 items from pretrained weights

# %%
test = model.predict('test_images/ramen_1.jpg')
# Out:
# image 1/1 /Users/jack/Library/CloudStorage/GoogleDrive-limjackailjk@gmail.com/My Drive/UCSD/Projects/AR-Food-Nutrition-Finder/test_images/ramen_1.jpg: 224x224 conch 0.79, hermit_crab 0.12, solar_dish 0.04, ballpoint 0.01, rock_crab 0.01, 25.4ms
# Speed: 27.7ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)

# %%
test[0].probs
# Out:
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.0044e-06, 3.5903e-10, 3.0085e-07, 5.5763e-10, 3.2538e-10, 2.0896e-08, 9.9106e-11, 4.6623e-11, 1.0904e-06, 1.5719e-10, 5.3628e-05, 4.2108e-08, 6.9841e-09, 2.9922e-07, 1.1994e-10, 8.7855e-09, 2.4877e-09, 6.4128e-09, 1.4348e-06, 5.2402e-08, 2.9521e-09, 1.7369e-13, 6.4236e-14, 3.5332e-10, 1.2054e-08, 7.2311e-12,
#         1.4955e-08, 7.0908e-08, 1.7247e-12, 9.6866e-12, 6.0592e-06, 1.8773e-10, 3.0393e-08, 5.9824e-09, 1.7841e-08, 1.2357e-09, 8.6345e-10, 1.8967e-08, 1.5929e-13, 2.6273e-05, 2.7673e-12, 5.3897e-12, 8.0449e-13, 7.1776e-10, 3.6143e-11, 7.4060e-10, 4.3091e-08, 9.9814e-12, 2.5430e-11, 6.6555e-09, 3.3857e-10, 2.1016e-06,
# ...
